# %%
# Cleaning the original csv dataset from Kaggle.
# Focus on defensive stats & salary.

# %%
import os

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# %%
ONE_SEASON_DIR = '../Dataset/nba_2017_nba_players_with_salary.csv'
THIRTY_TWO_SEASONS_DIR = '../Dataset/Seasons_Stats.csv'

# %%
df = pd.read_csv(ONE_SEASON_DIR)
df.head()
to_drop = ['Rk','FG', 'FGA','FG%','3P','3PA','3P%','2P','2PA','2P%','eFG%','FT','FTA',
           'FT%','TOV','POINTS','MPG','ORB','ORPM','TRB','RPM','PIE','PACE','W','WINS_RPM']
df.drop(to_drop, inplace=True, axis=1)
df.head()
# Out:
#    Unnamed: 0             PLAYER POSITION  AGE    MP  DRB   AST  STL  BLK  \
# 0           0  Russell Westbrook       PG   28  34.6  9.0  10.4  1.6  0.4
# 1           1       James Harden       PG   27  36.4  7.0  11.2  1.5  0.5
# 2           2      Isaiah Thomas       PG   27  33.8  2.1   5.9  0.9  0.2
# 3           3      Anthony Davis        C   23  36.1  9.5   2.1  1.3  2.2
# 4           4   DeMarcus Cousins        C   26  34.2  8.9   4.6  1.4  1.3
#
#     PF    TEAM  GP  DRPM  SALARY_MILLIONS
# 0  2.3     OKC  81 -0.47            26.50
# 1  2.7     HOU  81 -1.57            26.50
# 2  2.2     BOS  76 -3.89             6.59
# 3  2.2      NO  75  3.90            22.12
# 4  3.9  NO/SAC  72  0.64            16.96
